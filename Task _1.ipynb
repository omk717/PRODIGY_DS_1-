# %%
import os 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings

# %%
os.chdir(r"C:\Users\Omkar\Downloads\TASK 1")

# %%
df = pd.read_csv("Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_344131.csv")
df
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
df.head(50)
# Out:
#    Country Code                      Region          IncomeGroup  \
# 0           ABW   Latin America & Caribbean          High income
# 1           AFE                         NaN                  NaN
# 2           AFG                  South Asia           Low income
# 3           AFW                         NaN                  NaN
# 4           AGO          Sub-Saharan Africa  Lower middle income
# 5           ALB       Europe & Central Asia  Upper middle income
# 6           AND       Europe & Central Asia          High income
# 7           ARB                         NaN                  NaN
# 8           ARE  Middle East & North Africa          High income
# 9           ARG   Latin America & Caribbean  Upper middle income
# 10          ARM       Europe & Central Asia  Upper middle income
# 11          ASM         East Asia & Pacific          High income
# 12          ATG   Latin America & Caribbean          High income
# ...

# %%
gender_counts = df['Region'].value_counts()

plt.figure(figsize=(10, 6))
plt.bar(gender_counts.index, gender_counts.values, width=0.9)
plt.xlabel('Region')
plt.ylabel('Count')
plt.title('Distribution of Region')

plt.xticks(gender_counts.index, rotation=45)
plt.tight_layout()
plt.show()

# %%
df.shape
# Out:
# (265, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  265 non-null    object
#  1   Region        217 non-null    object
#  2   IncomeGroup   216 non-null    object
#  3   SpecialNotes  126 non-null    object
#  4   TableName     265 non-null    object
#  5   Unnamed: 5    0 non-null      float64
# dtypes: float64(1), object(5)
# memory usage: 12.6+ KB

# %%
df.describe()
# Out:
#        Unnamed: 5
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
df.isnull().sum()
# Out:
# Country Code      0
# Region           48
# IncomeGroup      49
# SpecialNotes    139
# TableName         0
# Unnamed: 5      265
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  265 non-null    object
#  1   Region        217 non-null    object
#  2   IncomeGroup   216 non-null    object
#  3   SpecialNotes  126 non-null    object
#  4   TableName     265 non-null    object
#  5   Unnamed: 5    0 non-null      float64
# dtypes: float64(1), object(5)
# memory usage: 12.6+ KB

# %%
np.random.seed(42)
ages = np.random.randint(1, 100, size=1000)  
genders = np.random.choice(['Male', 'Female'], size=1000)  

data = pd.DataFrame({'Age': ages, 'Gender': genders})

plt.figure(figsize=(10, 6))
sns.histplot(data['Age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

plt.figure(figsize=(10, 6))
sns.countplot(x='Gender', data=data)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Omkar\Downloads\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
